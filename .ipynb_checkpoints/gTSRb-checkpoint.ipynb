# %% [markdown]
# # Classification of Traffic Signs (gTSRb data set)

# %%
# FUNCTION FOR LOADING IMAGES         
# trainImages, trainLabels = readTrafficSigns('GTSRB/Training')
# print len(trainLabels), len(trainImages)
# plt.imshow(trainImages[42])
# plt.show()
#
# have fun, Christian

import matplotlib.pyplot as plt
import csv

# function for reading the images
# arguments: path to the traffic sign data, for example './GTSRB/Training'
# returns: list of images, list of corresponding labels 
def readTrafficSigns(rootpath):
    '''Reads traffic sign data for German Traffic Sign Recognition Benchmark.

    Arguments: path to the traffic sign data, for example './GTSRB/Training'
    Returns:   list of images, list of corresponding labels'''
    images = [] # images
    labels = [] # corresponding labels
    dims = [] # images dims
    rois = [] # strict RoIs of signs
    # loop over all 42 classes
    for c in range(0,43):
        prefix = rootpath + '/' + format(c, '05d') + '/' # subdirectory for class
        gtFile = open(prefix + 'GT-'+ format(c, '05d') + '.csv') # annotations file
        gtReader = csv.reader(gtFile, delimiter=';') # csv parser for annotations file
        gtReader.next() # skip header
        # loop over all images in current annotations file
        for row in gtReader:
            images.append(plt.imread(prefix + row[0])) # the 1th column is the filename
            labels.append(row[7]) # the 8th column is the label
            dims.append( (row[1],row[2]) )
            rois.append( (row[3],row[4],row[5],row[6]) )
        gtFile.close()
    return images, labels, dims, rois

# %% [markdown]
# ## Load training and testing images

# %%
# Load training images
img, label, dims, rois = readTrafficSigns('./Training')

# Load testing images
img_tst, label_tst, dims_tst, rois_tst = readTrafficSigns('./Testing')

# %% [markdown]
# ## Resize uniformly training and testing images, shuffle training set, and plot some examples

# %%
import numpy as np
from sklearn.utils import shuffle
import skimage
#from skimage.util import crop
from skimage.transform import resize
from skimage.util import img_as_float32

img_size = 32

# Resize UNIFORMLY training images
arr_train_img = np.asarray(img)
y_train = np.asarray(label)
X_train_img = arr_train_img
for i in range(0,arr_train_img.size):
  #afterI = rois[i][2] - dims[i][0]
  #afterJ = rois[i][3] - dims[i][1]
  #X_train_img[i] = crop(arr_train_img[i], ( (rois[i][0], afterI), (rois[i][1], afterJ) ), True )
  X_train_img[i] = resize(arr_train_img[i], (img_size,img_size) )
                       
# Shuffle the training set (originally ordered by class after loading)
X_train_img, y_train = shuffle(X_train_img, y_train)

# Reformat training set as bi-dimensional array
n_train = X_train_img.shape[0]
input_dim = img_size*img_size*3
X_train = np.zeros( (n_train,input_dim) )
for i in range(0,X_train_img.size):
  X_train[i] = np.ravel( img_as_float32(X_train_img[i], True) )
print("Number of TRAINING examples = ",X_train.shape[0])

# Resize UNIFORMLY testing images
arr_test_img = np.asarray(img_tst)
y_test = np.asarray(label_tst)
X_test_img = arr_test_img
for i in range(0,arr_test_img.size):
  #afterI = rois[i][2] - dims[i][0]
  #afterJ = rois[i][3] - dims[i][1]
  #X_train_img[i] = crop(arr_train_img[i], ( (rois[i][0], afterI), (rois[i][1], afterJ) ), True )
  X_test_img[i] = resize(arr_test_img[i], (img_size,img_size) )
    
# Reformat training set as bi-dimensional array
n_test = X_test_img.shape[0]
input_dim = img_size*img_size*3
X_test = np.zeros( (n_test,input_dim) )
for i in range(0,X_test_img.size):
  X_test[i] = np.ravel( img_as_float32(X_test_img[i], True) )
print("Number of TESTING examples = "+X_test.shape[0])

# Visualize some training examples
class_names = label
for i in range(0,5):
 plt.figure()
 plt.imshow(X_train_img[i])
 plt.show()
 print(y_train[i])
# Out:
# (26640L, 3072L)
# (12569L, 3072L)
# 13
# 12
# 40
# 27
# 18

# %% [markdown]
# # A first BASELINE classifier

# %%
from sklearn.neural_network import MLPClassifier

mlp = MLPClassifier(hidden_layer_sizes=(300,), max_iter=30, alpha=1e-4,
                    solver='sgd', verbose=10, tol=1e-4, random_state=1,
                    learning_rate_init=0.03)

mlp.fit(X_train, y_train)
print("Training set score: %f" % mlp.score(X_train, y_train))

print("Test set score: %f" % mlp.score(X_test, y_test))

y_pred = mlp.predict(X_test)
from sklearn.metrics import classification_report
print("Detailed classification report:")
print(classification_report(y_test, y_pred))
# Out:
# Iteration 1, loss = 2.04343158
# Iteration 2, loss = 0.86266116
# Iteration 3, loss = 0.56842905
# Iteration 4, loss = 0.43953886
# Iteration 5, loss = 0.36602023
# Iteration 6, loss = 0.31002157
# Iteration 7, loss = 0.27102547
# Iteration 8, loss = 0.23969374
# Iteration 9, loss = 0.21881853
# Iteration 10, loss = 0.20035113
# Iteration 11, loss = 0.18865092
# Iteration 12, loss = 0.17115510
# Iteration 13, loss = 0.15451533
# Iteration 14, loss = 0.14912509
# Iteration 15, loss = 0.13888557
# Iteration 16, loss = 0.12408006
# Iteration 17, loss = 0.12068346
# Iteration 18, loss = 0.11721865
# Iteration 19, loss = 0.10973748
# Iteration 20, loss = 0.10370668
# Iteration 21, loss = 0.10067878
# Iteration 22, loss = 0.08958896
# Iteration 23, loss = 0.08956411
# Iteration 24, loss = 0.08532957
# Iteration 25, loss = 0.07987042
# Iteration 26, loss = 0.07531147
# Iteration 27, loss = 0.07167024
# Iteration 28, loss = 0.06828976
# Iteration 29, loss = 0.06626554
# Iteration 30, loss = 0.06447972
# C:\Users\fm\Anaconda2\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (30) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Training set score: 0.992755
# Test set score: 0.860769
# Detailed classification report:
#              precision    recall  f1-score   support
#
#           0       0.82      0.23      0.36        60
#           1       0.81      0.90      0.85       720
#          10       0.95      0.97      0.96       660
#          11       0.85      0.87      0.86       420
#          12       0.97      0.95      0.96       690
#          13       0.95      0.94      0.95       720
#          14       0.98      0.85      0.91       240
#          15       0.86      0.83      0.85       210
#          16       0.96      0.61      0.74       120
#          17       0.91      0.98      0.95       360
#          18       0.87      0.86      0.86       390
#          19       0.68      0.88      0.77        60
#           2       0.84      0.87      0.85       750
#          20       0.36      0.66      0.47       120
#          21       0.71      0.17      0.27        90
#          22       0.96      0.86      0.91       120
#          23       0.75      0.45      0.56       150
#          24       0.70      0.59      0.64        90
#          25       0.98      0.87      0.92       480
#          26       0.72      0.76      0.74       180
#          27       0.83      0.50      0.62        60
#          28       0.84      0.81      0.82       180
#          29       0.49      0.46      0.47        90
#           3       0.84      0.84      0.84       450
#          30       0.72      0.76      0.74       150
#          31       0.80      0.82      0.81       240
#          32       0.67      1.00      0.81        60
#          33       0.86      0.97      0.91       209
#          34       0.98      0.98      0.98       120
#          35       0.98      0.95      0.97       390
#          36       0.92      0.99      0.95       120
#          37       0.87      0.98      0.92        60
#          38       0.96      0.93      0.95       690
#          39       1.00      0.62      0.77        90
#           4       0.85      0.85      0.85       660
#          40       0.91      0.70      0.79       120
#          41       0.60      0.87      0.71        60
#          42       1.00      0.35      0.52        60
#           5       0.74      0.86      0.79       600
#           6       0.88      0.95      0.92       120
#           7       0.79      0.89      0.84       480
#           8       0.83      0.81      0.82       450
#           9       0.95      0.90      0.93       480
#
# avg / total       0.87      0.86      0.86     12569
